# %%
import pandas as pd 
df =pd.read_csv(r'C:\Users\AFAK\Downloads\archive (4)\vgsales.csv')
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df.drop_duplicates()
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df.dropna
# Out:
# <bound method DataFrame.dropna of         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
# ...

# %%
df=df[df['Global_Sales']>=0]

# %%
def level_year(Year):
   if 2000<=Year<=2025:
    return 'l1'
   elif 1850<=Year<2000:
     return 'l2'
   else :
     return 'other'
     print(Year)     
level_year=df['Year'].apply(level_year)
level_year.reset_index()
df['level_year']=level_year
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
test=df.loc[16596]
test
# Out:
# Rank                 16599
# Name            Know How 2
# Platform                DS
# Year                2010.0
# Genre               Puzzle
# Publisher         7G//AMES
# NA_Sales               0.0
# EU_Sales              0.01
# JP_Sales               0.0
# Other_Sales            0.0
# Global_Sales          0.01
# level_year              l1
# Name: 16596, dtype: object

# %%
global_sales_by_year=df.groupby('Year')['Global_Sales'].sum().sort_values(ascending=False)
global_sales_by_year.reset_index()
# Out:
#       Year  Global_Sales
# 0   2008.0        678.90
# 1   2009.0        667.30
# 2   2007.0        611.13
# 3   2010.0        600.45
# 4   2006.0        521.04
# 5   2011.0        515.99
# 6   2005.0        459.94
# 7   2004.0        419.31
# 8   2002.0        395.52
# 9   2013.0        368.11
# 10  2012.0        363.54
# 11  2003.0        357.85
# 12  2014.0        337.05
# 13  2001.0        331.47
# 14  2015.0        264.44
# 15  1998.0        256.47
# 16  1999.0        251.27
# 17  2000.0        201.56
# 18  1997.0        200.98
# 19  1996.0        199.15
# 20  1995.0         88.11
# 21  1994.0         79.17
# 22  1992.0         76.16
# 23  1989.0         73.45
# 24  2016.0         70.93
# 25  1985.0         53.94
# 26  1984.0         50.36
# 27  1990.0         49.39
# 28  1988.0         47.22
# 29  1993.0         45.98
# 30  1986.0         37.07
# 31  1981.0         35.77
# 32  1991.0         32.23
# 33  1982.0         28.86
# 34  1987.0         21.74
# 35  1983.0         16.79
# ...

# %%
global_sales_by_year=df.groupby('level_year')['Global_Sales'].sum().sort_values(ascending=False)
global_sales_by_year=global_sales_by_year.reset_index()

# %%
Global_Sales_l1_mor2000_and_l2less2000=global_sales_by_year.to_excel('Global_Sales_l1_mor2000_and_l2less2000.xlsx')

# %%
df_other = df[df['level_year'] == 'other']
df_other
# Out:
#         Rank                         Name Platform  Year         Genre  \
# 179      180              Madden NFL 2004      PS2   NaN        Sports
# 377      378             FIFA Soccer 2004      PS2   NaN        Sports
# 431      432   LEGO Batman: The Videogame      Wii   NaN        Action
# 470      471   wwe Smackdown vs. Raw 2006      PS2   NaN      Fighting
# 607      608               Space Invaders     2600   NaN       Shooter
# ...      ...                          ...      ...   ...           ...
# 16307  16310                Freaky Flyers       GC   NaN        Racing
# 16327  16330                    Inversion       PC   NaN       Shooter
# 16366  16369  Hakuouki: Shinsengumi Kitan      PS3   NaN     Adventure
# 16427  16430                 Virtua Quest       GC   NaN  Role-Playing
# 16493  16496                   The Smurfs      3DS   NaN        Action
#
#                                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
sales=[]

# %%
sales_by_region_NA_Sales=df['NA_Sales'].sum()
sales_by_region_NA_Sales
sales.append(sales_by_region_NA_Sales)

# %%
sales_by_region_EU_Sales=df['EU_Sales'].sum()
sales_by_region_EU_Sales
sales.append(sales_by_region_EU_Sales)

# %%
sales_by_region_JP_Sales=df['JP_Sales'].sum()
sales_by_region_JP_Sales
sales.append(sales_by_region_JP_Sales)

# %%
global_sales_by_Genre=df.groupby('Genre')['NA_Sales'].sum().sort_values(ascending=False)
global_sales_by_Genre.reset_index()
# Out:
#            Genre  NA_Sales
# 0         Action    877.83
# 1         Sports    683.35
# 2        Shooter    582.60
# 3       Platform    447.05
# 4           Misc    410.24
# 5         Racing    359.42
# 6   Role-Playing    327.28
# 7       Fighting    223.59
# 8     Simulation    183.31
# 9         Puzzle    123.78
# 10     Adventure    105.80
# 11      Strategy     68.70

# %%
sales_by_region_Other_Sales=df['Other_Sales'].sum()
sales_by_region_Other_Sales
sales.append(sales_by_region_Other_Sales)

# %%
global_sales_by_Genre=df.groupby('Genre')['Global_Sales'].sum().sort_values(ascending=False)
global_sales_by_Genre
# Out:
# Genre
# Action          1751.18
# Sports          1330.93
# Shooter         1037.37
# Role-Playing     927.37
# Platform         831.37
# Misc             809.96
# Racing           732.04
# Fighting         448.91
# Simulation       392.20
# Puzzle           244.95
# Adventure        239.04
# Strategy         175.12
# Name: Global_Sales, dtype: float64

# %%
import matplotlib.pyplot as plt 
#sales.dataFrame(sales)
plt.figure(figsize=(15,5))
plt.plot (global_sales_by_Genre)
plt.title('sales&region')
plt.xlabel('Genre')
plt.ylabel('Global_Sales')
# Out:
# Text(0, 0.5, 'Global_Sales')

# %%
global_sales_by_Genre=df.groupby('Genre')['NA_Sales'].sum().sort_values(ascending=False)
global_sales_by_Genre_NA=global_sales_by_Genre.reset_index()
global_sales_by_Genre_NA.to_excel('global_sales_by_Genre_NA.xlsx')

# %%
global_sales_by_Genre=df.groupby('Genre')['JP_Sales'].sum().sort_values(ascending=False)
global_sales_by_Genrejp=global_sales_by_Genre.reset_index()
global_sales_by_Genrejp.to_excel('global_sales_by_Genrejp.xlsx')

# %%
global_sales_by_Genre=df.groupby('Genre')['EU_Sales'].sum().sort_values(ascending=False)
global_sales_by_Genre_EU=global_sales_by_Genre.reset_index()
global_sales_by_Genre_EU.to_excel('global_sales_by_Genre_EU.xlsx')

# %%
global_sales_by_Genre=df.groupby('Genre')['Other_Sales'].sum().sort_values(ascending=False)
global_sales_by_Genre.reset_index()
# Out:
#            Genre  Other_Sales
# 0         Action       187.38
# 1         Sports       134.97
# 2        Shooter       102.69
# 3         Racing        77.27
# 4           Misc        75.32
# 5   Role-Playing        59.61
# 6       Platform        51.59
# 7       Fighting        36.68
# 8     Simulation        31.52
# 9      Adventure        16.81
# 10        Puzzle        12.55
# 11      Strategy        11.36

# %%
sales
# Out:
# [4392.950000000001, 2434.1299999999997, 1291.0200000000002, 797.7500000000001]

# %%
import pandas as pd

sales = pd.DataFrame({
    'sales': [4392.95, 2434.13, 1291.02, 797.75],
    'Region': ['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']
})

sales=sales.reset_index()
sum_of_sales_every_region=sales.to_excel('sum_of_sales_every_region.xlsx')

# %%
sum_of_sales_every_region=sales.to_excel('sum_of_sales_every_region.xlsx')

# %%
import matplotlib.pyplot as plt 
#sales.dataFrame(sales)

plt.plot (sales['sales'],sales['Region'])
plt.title('sales&region')
plt.xlabel('sales')
plt.ylabel('region')
# Out:
# Text(0, 0.5, 'region')
